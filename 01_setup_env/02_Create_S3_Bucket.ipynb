# %% [markdown]
# # Create S3 Bucket

# %%
pip install --upgrade boto3 botocore awscli
# Out:
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.12/site-packages (1.43.11)
# Requirement already satisfied: botocore in /opt/conda/lib/python3.12/site-packages (1.43.11)
# Requirement already satisfied: awscli in /opt/conda/lib/python3.12/site-packages (1.45.11)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3) (1.1.0)
# Requirement already satisfied: s3transfer<0.18.0,>=0.17.0 in /opt/conda/lib/python3.12/site-packages (from boto3) (0.17.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from botocore) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.12/site-packages (from botocore) (1.26.20)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore) (1.17.0)
# Requirement already satisfied: docutils<=0.19,>=0.18.1 in /opt/conda/lib/python3.12/site-packages (from awscli) (0.19)
# Requirement already satisfied: PyYAML<6.1,>=3.10 in /opt/conda/lib/python3.12/site-packages (from awscli) (6.0.3)
# Requirement already satisfied: colorama<0.4.7,>=0.2.5 in /opt/conda/lib/python3.12/site-packages (from awscli) (0.4.6)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from awscli) (4.7.2)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.12/site-packages (from rsa<4.8,>=3.1.2->awscli) (0.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install compatible SageMaker SDK version
# !pip install "sagemaker<3.0.0"
# Out:
# Requirement already satisfied: sagemaker<3.0.0 in /opt/conda/lib/python3.12/site-packages (2.257.3)
# Requirement already satisfied: attrs<26,>=24 in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (25.4.0)
# Requirement already satisfied: boto3<2.0,>=1.42.2 in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (1.43.11)
# Requirement already satisfied: cloudpickle>=2.2.1 in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (3.1.2)
# Requirement already satisfied: docker in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (7.1.0)
# Requirement already satisfied: fastapi in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (0.136.1)
# Requirement already satisfied: google-pasta in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (0.2.0)
# Requirement already satisfied: graphene<4,>=3 in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (3.4.3)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (6.10.0)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (4.23.0)
# Requirement already satisfied: numpy<3.0,>=1.26.4 in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (1.26.4)
# Requirement already satisfied: omegaconf<3,>=2.2 in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (2.3.0)
# Requirement already satisfied: packaging<25,>=23.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (24.2)
# Requirement already satisfied: pandas>=2.3.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (2.3.3)
# Requirement already satisfied: pathos in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (0.3.5)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (4.9.6)
# Requirement already satisfied: protobuf<7.0,>=3.12 in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (6.31.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (5.9.8)
# Requirement already satisfied: pyyaml>=6.0.1 in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (6.0.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (2.33.1)
# Requirement already satisfied: sagemaker-core<2.0.0,>=1.0.71 in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (1.0.78)
# Requirement already satisfied: schema in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (0.7.7)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (1.0.1)
# Requirement already satisfied: tblib<4,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (3.2.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (4.67.3)
# Requirement already satisfied: urllib3<3.0.0,>=1.26.8 in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (1.26.20)
# Requirement already satisfied: uvicorn in /opt/conda/lib/python3.12/site-packages (from sagemaker<3.0.0) (0.46.0)
# Requirement already satisfied: botocore<1.44.0,>=1.43.11 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0,>=1.42.2->sagemaker<3.0.0) (1.43.11)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0,>=1.42.2->sagemaker<3.0.0) (1.1.0)
# Requirement already satisfied: s3transfer<0.18.0,>=0.17.0 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0,>=1.42.2->sagemaker<3.0.0) (0.17.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from botocore<1.44.0,>=1.43.11->boto3<2.0,>=1.42.2->sagemaker<3.0.0) (2.9.0.post0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /opt/conda/lib/python3.12/site-packages (from graphene<4,>=3->sagemaker<3.0.0) (3.2.8)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /opt/conda/lib/python3.12/site-packages (from graphene<4,>=3->sagemaker<3.0.0) (3.2.0)
# Requirement already satisfied: typing-extensions<5,>=4.7.1 in /opt/conda/lib/python3.12/site-packages (from graphene<4,>=3->sagemaker<3.0.0) (4.15.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker<3.0.0) (3.23.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/conda/lib/python3.12/site-packages (from omegaconf<3,>=2.2->sagemaker<3.0.0) (4.9.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.44.0,>=1.43.11->boto3<2.0,>=1.42.2->sagemaker<3.0.0) (1.17.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.71->sagemaker<3.0.0) (2.13.3)
# Requirement already satisfied: rich<15.0.0,>=13.0.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.71->sagemaker<3.0.0) (14.3.4)
# Requirement already satisfied: mock<5.0,>4.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.71->sagemaker<3.0.0) (4.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema->sagemaker<3.0.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema->sagemaker<3.0.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema->sagemaker<3.0.0) (0.27.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.71->sagemaker<3.0.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.71->sagemaker<3.0.0) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.71->sagemaker<3.0.0) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.71->sagemaker<3.0.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.71->sagemaker<3.0.0) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.71->sagemaker<3.0.0) (0.1.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas>=2.3.0->sagemaker<3.0.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas>=2.3.0->sagemaker<3.0.0) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->sagemaker<3.0.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->sagemaker<3.0.0) (3.13)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.12/site-packages (from requests->sagemaker<3.0.0) (2026.4.22)
# Requirement already satisfied: starlette>=0.46.0 in /opt/conda/lib/python3.12/site-packages (from fastapi->sagemaker<3.0.0) (1.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/conda/lib/python3.12/site-packages (from fastapi->sagemaker<3.0.0) (0.0.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in /opt/conda/lib/python3.12/site-packages (from starlette>=0.46.0->fastapi->sagemaker<3.0.0) (4.13.0)
# Requirement already satisfied: ppft>=1.7.8 in /opt/conda/lib/python3.12/site-packages (from pathos->sagemaker<3.0.0) (1.7.8)
# Requirement already satisfied: dill>=0.4.1 in /opt/conda/lib/python3.12/site-packages (from pathos->sagemaker<3.0.0) (0.4.1)
# Requirement already satisfied: pox>=0.3.7 in /opt/conda/lib/python3.12/site-packages (from pathos->sagemaker<3.0.0) (0.3.7)
# Requirement already satisfied: multiprocess>=0.70.19 in /opt/conda/lib/python3.12/site-packages (from pathos->sagemaker<3.0.0) (0.70.19)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.12/site-packages (from uvicorn->sagemaker<3.0.0) (8.2.1)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.12/site-packages (from uvicorn->sagemaker<3.0.0) (0.16.0)

# %%
import boto3
import sagemaker

session = boto3.session.Session()
region = session.region_name
sagemaker_session = sagemaker.Session()
bucket = sagemaker_session.default_bucket()

s3 = boto3.Session().client(service_name="s3", region_name=region)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %%
setup_s3_bucket_passed = False

# %%
print("Default bucket: {}".format(bucket))
# Out:
# Default bucket: sagemaker-us-east-1-646180330281

# %% [markdown]
# # Verify S3_BUCKET Bucket Creation

# %%
from botocore.client import ClientError

response = None

try:
    response = s3.head_bucket(Bucket=bucket)
    print(response)
    setup_s3_bucket_passed = True
except ClientError as e:
    print("[ERROR] Cannot find bucket {} in {} due to {}.".format(bucket, response, e))
# Out:
# {'ResponseMetadata': {'RequestId': 'YTESBWD00WBNZA4W', 'HostId': 'Wb5xRjNHWrIleEizf71OUHT/J6RGyPlHdAF/ZwL10f0ogVp8KKrCDoVAQxHZnii6nI0PFdAYjoD2AVPqI1C1/w3ljbz9/jaH', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'Wb5xRjNHWrIleEizf71OUHT/J6RGyPlHdAF/ZwL10f0ogVp8KKrCDoVAQxHZnii6nI0PFdAYjoD2AVPqI1C1/w3ljbz9/jaH', 'x-amz-request-id': 'YTESBWD00WBNZA4W', 'date': 'Wed, 20 May 2026 00:40:07 GMT', 'x-amz-bucket-region': 'us-east-1', 'x-amz-access-point-alias': 'false', 'x-amz-bucket-arn': 'arn:aws:s3:::sagemaker-us-east-1-646180330281', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'BucketArn': 'arn:aws:s3:::sagemaker-us-east-1-646180330281', 'BucketRegion': 'us-east-1', 'AccessPointAlias': False}

# %%
# %store setup_s3_bucket_passed
# Out:
# Stored 'setup_s3_bucket_passed' (bool)

# %%
# %store
# Out:
# Stored variables and their in-db values:
# setup_dependencies_passed             -> True
# setup_s3_bucket_passed                -> True

# %% [markdown]
# # Release Resources

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
# Out:
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>

# %%
# %%javascript
#
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {
#     // NoOp
# }
