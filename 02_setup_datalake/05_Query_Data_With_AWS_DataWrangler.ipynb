# %% [markdown]
# # Query Data with AWS Data Wrangler

# %% [markdown]
# **AWS Data Wrangler** is an open-source Python library that extends the power of the Pandas library to AWS connecting DataFrames and AWS data related services (Amazon Redshift, AWS Glue, Amazon Athena, Amazon EMR, Amazon QuickSight, etc).
#
# * https://github.com/awslabs/aws-data-wrangler
# * https://aws-data-wrangler.readthedocs.io
#
# Built on top of other open-source projects like Pandas, Apache Arrow, Boto3, s3fs, SQLAlchemy, Psycopg2 and PyMySQL, it offers abstracted functions to execute usual ETL tasks like load/unload data from Data Lakes, Data Warehouses and Databases.
#
# _Note that AWS Data Wrangler is simply a Python library that uses existing AWS Services.  AWS Data Wrangler is not a separate AWS Service.  You install AWS Data Wrangler through `pip install` as we will see next._

# %% [markdown]
# # _Pre-Requisite: Make Sure You Created an Athena Table for Both TSV and Parquet in Previous Notebooks_

# %%
# %store -r ingest_create_athena_table_tsv_passed

# %%
try:
    ingest_create_athena_table_tsv_passed
except NameError:
    print("++++++++++++++++++++++++++++++++++++++++++++++")
    print("[ERROR] YOU HAVE TO RUN ALL PREVIOUS NOTEBOOKS.  You did not register the TSV Data.")
    print("++++++++++++++++++++++++++++++++++++++++++++++")

# %%
print(ingest_create_athena_table_tsv_passed)
# Out:
# True

# %%
if not ingest_create_athena_table_tsv_passed:
    print("++++++++++++++++++++++++++++++++++++++++++++++")
    print("[ERROR] YOU HAVE TO RUN ALL PREVIOUS NOTEBOOKS.  You did not register the TSV Data.")
    print("++++++++++++++++++++++++++++++++++++++++++++++")
else:
    print("[OK]")
# Out:
# [OK]

# %%
# %store -r ingest_create_athena_table_parquet_passed

# %%
try:
    ingest_create_athena_table_parquet_passed
except NameError:
    print("++++++++++++++++++++++++++++++++++++++++++++++")
    print("[ERROR] YOU HAVE TO RUN ALL PREVIOUS NOTEBOOKS.  You did not convert into Parquet data.")
    print("++++++++++++++++++++++++++++++++++++++++++++++")

# %%
print(ingest_create_athena_table_parquet_passed)
# Out:
# True

# %%
if not ingest_create_athena_table_parquet_passed:
    print("++++++++++++++++++++++++++++++++++++++++++++++")
    print("[ERROR] YOU HAVE TO RUN ALL PREVIOUS NOTEBOOKS.  You did not convert into Parquet data.")
    print("++++++++++++++++++++++++++++++++++++++++++++++")
else:
    print("[OK]")
# Out:
# [OK]

# %% [markdown]
# # Setup

# %%
import sagemaker
import boto3

sess = sagemaker.Session()
bucket = sess.default_bucket()
role = sagemaker.get_execution_role()
region = boto3.Session().region_name

sm = boto3.Session().client(service_name="sagemaker", region_name=region)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %%
import awswrangler as wr

# %% [markdown]
# # Query Parquet from S3 with Push-Down Filters
#
# Read Apache Parquet file(s) from from a received S3 prefix or list of S3 objects paths.
#
# The concept of Dataset goes beyond the simple idea of files and enable more complex features like partitioning and catalog integration (AWS Glue Catalog):
#
# _dataset (bool)_ – If True read a parquet dataset instead of simple file(s) loading all the related partitions as columns.

# %%
p_filter = lambda x: x["product_category"] == "Digital_Software"

# %%
path = "s3://{}/amazon-reviews-pds/parquet/".format(bucket)
df_parquet_results = wr.s3.read_parquet(
    path, columns=["star_rating", "product_category", "review_body"], partition_filter=p_filter, dataset=True
)
df_parquet_results.shape
# Out:
# 2026-05-20 02:46:11,047	WARNING services.py:2137 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 1909436416 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=4.62gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2026-05-20 02:46:12,188	INFO worker.py:2007 -- Started a local Ray instance.
# /opt/conda/lib/python3.12/site-packages/ray/_private/worker.py:2046: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# (102084, 3)

# %%
df_parquet_results.head(5)
# Out:
#    star_rating                                        review_body  \
# 0            4                                     So far so good
# 1            3                      Needs a little more work.....
# 2            1                                     Please cancel.
# 3            5                                 Works as Expected!
# 4            4  I've had Webroot for a few years. It expired a...
#
#    product_category
# 0  Digital_Software
# 1  Digital_Software
# 2  Digital_Software
# 3  Digital_Software
# 4  Digital_Software

# %% [markdown]
# # Query Parquet from S3 in Chunks

# %% [markdown]
# Batching (chunked argument) (Memory Friendly):
#
# Will enable the function to return a Iterable of DataFrames instead of a regular DataFrame.
#
# There are two batching strategies on Wrangler:
# * If chunked=True, a new DataFrame will be returned for each file in your path/dataset.
# * If chunked=INTEGER, Wrangler will iterate on the data by number of rows equal to the received INTEGER.
#
# P.S. chunked=True if faster and uses less memory while chunked=INTEGER is more precise in number of rows for each Dataframe.

# %%
path = "s3://{}/amazon-reviews-pds/parquet/".format(bucket)
chunk_iter = wr.s3.read_parquet(
    path,
    columns=["star_rating", "review_body"],
    # filters=[("product_category", "=", "Digital_Software")],
    partition_filter=p_filter,
    dataset=True,
    chunked=True,
)

# %%
print(next(chunk_iter))
# Out:
#        star_rating                                        review_body  \
# 0                4                                     So far so good
# 1                3                      Needs a little more work.....
# 2                1                                     Please cancel.
# 3                5                                 Works as Expected!
# 4                4  I've had Webroot for a few years. It expired a...
# ...            ...                                                ...
# 65531            5                    Very handy, I use it every day.
# 65532            5  This has been a great program for me.  When it...
# 65533            1  Enough is enough! This bloated, poorly designe...
# 65534            3  It's just okay now, not much has changed with ...
# 65535            5  Program was easy to install and get going from...
#
#        product_category
# 0      Digital_Software
# 1      Digital_Software
# 2      Digital_Software
# 3      Digital_Software
# 4      Digital_Software
# ...                 ...
# 65531  Digital_Software
# 65532  Digital_Software
# 65533  Digital_Software
# 65534  Digital_Software
# 65535  Digital_Software
#
# [65536 rows x 3 columns]

# %% [markdown]
# # Query the Glue Catalog (ie. Hive Metastore)
# Get an iterator of tables.

# %%
database_name = "dsoaws"
table_name_tsv = "amazon_reviews_tsv"
table_name_parquet = "amazon_reviews_parquet"

# %%
for table in wr.catalog.get_tables(database="dsoaws"):
    print(table["Name"])
# Out:
# amazon_reviews_parquet
# amazon_reviews_tsv

# %% [markdown]
# # Query from Athena
# Execute any SQL query on AWS Athena and return the results as a Pandas DataFrame.

# %%
# %%time
df = wr.athena.read_sql_query(sql="SELECT * FROM {} LIMIT 5000".format(table_name_parquet), database=database_name)
# Out:
# CPU times: user 949 ms, sys: 250 ms, total: 1.2 s
# Wall time: 4.32 s

# %%
df.head(5)
# Out:
#   marketplace customer_id       review_id  product_id product_parent  \
# 0          US    17747349  R2EI7QLPK4LF7U  B00U7LCE6A      106182406
# 1          US    10956619  R1W5OMFK1Q3I3O  B00HRJMOM4      162269768
# 2          US    13132245   RPZWSYWRP92GI  B00P31G9PQ      831433899
# 3          US    35717248  R2WQWM04XHD9US  B00FGDEPDY      991059534
# 4          US    17710652  R1WSPK2RA2PDEF  B00FZ0FK0U      574904556
#
#                                        product_title  star_rating  \
# 0                           CCleaner Free [Download]            4
# 1                 ResumeMaker Professional Deluxe 18            3
# 2                          Amazon Drive Desktop [PC]            1
# 3         Norton Internet Security 1 User 3 Licenses            5
# 4  SecureAnywhere Intermet Security Complete 5 De...            4
#
#    helpful_votes  total_votes vine verified_purchase  \
# 0              0            0    N                 Y
# 1              0            0    N                 Y
# 2              1            2    N                 Y
# 3              0            0    N                 Y
# 4              1            2    N                 Y
#
#                                review_headline  \
# 0                                   Four Stars
# 1                                  Three Stars
# 2                                     One Star
# 3                           Works as Expected!
# 4  Great antivirus. Worthless customer support
#
#                                          review_body  year review_date  \
# 0                                     So far so good  2015  2015-08-31
# 1                      Needs a little more work.....  2015  2015-08-31
# 2                                     Please cancel.  2015  2015-08-31
# 3                                 Works as Expected!  2015  2015-08-31
# 4  I've had Webroot for a few years. It expired a...  2015  2015-08-31
#
#    product_category
# 0  Digital_Software
# 1  Digital_Software
# 2  Digital_Software
# 3  Digital_Software
# 4  Digital_Software

# %% [markdown]
# # Query from Athena in Chunks
# Retrieving in chunks can help reduce memory requirements.
#
# _This will take a few seconds._

# %%
# %%time

chunk_iter = wr.athena.read_sql_query(
    sql="SELECT * FROM {} LIMIT 5000".format(table_name_parquet),
    database="{}".format(database_name),
    chunksize=64_000,  # 64 KB Chunks
)
# Out:
# CPU times: user 1.23 s, sys: 334 ms, total: 1.56 s
# Wall time: 4.43 s

# %%
print(next(chunk_iter))
# Out:
#      marketplace customer_id       review_id  product_id product_parent  \
# 0             US    24371595  R27ZP1F1CD0C3Y  B004LLIL5A      346014806
# 1             US    42489718   RJ7RSBCHUDNNE  B004LLIKVU      473048287
# 2             US      861463  R1HVYBSKLQJI5S  B00IX1I3G6      926539283
# 3             US    25283295  R2HAXF0IIYQBIR  B00IX1I3G6      926539283
# 4             US      397970   RNYLPX611NB7Q  B005ESMGV4      379368939
# ...          ...         ...             ...         ...            ...
# 4995          US    13567897  R3SVYO2YAVKB9M  B007RFEM32      743153911
# 4996          US    40575393  R3O7KVCUFJM3XM  B00BWDH3VS      473048287
# 4997          US    16217255  R28KNDYTUF7IK9  B004LLIL5U      864052097
# 4998          US    15748914   ROCZFMGHD420K  B004LLILFA      361255549
# 4999          US    39933351  R2NXA2EIW8IM4T  B00CT79XPU      473048287
#
#                                           product_title  star_rating  \
# 0                         Amazon eGift Card - Celebrate            5
# 1                                Amazon.com eGift Cards            5
# 2                   Amazon.com Gift Card Balance Reload            5
# 3                   Amazon.com Gift Card Balance Reload            1
# 4     Amazon.com Gift Cards, Pack of 3 (Various Desi...            5
# ...                                                 ...          ...
# 4995  Amazon.com Gift Card in a White Gift Box (Clas...            2
# 4996                             Amazon.com eGift Cards            5
# 4997                     Amazon eGift Card - Graduation            1
# 4998  Amazon eGift Card - Thank You, Teacher (Chalkb...            5
# 4999                             Amazon.com eGift Cards            5
#
#       helpful_votes  total_votes vine verified_purchase  \
# 0                 0            0    N                 Y
# 1                 0            0    N                 Y
# 2                 0            0    N                 Y
# 3                 0            0    N                 Y
# 4                 0            0    N                 Y
# ...             ...          ...  ...               ...
# 4995              1            1    N                 Y
# 4996              0            0    N                 Y
# 4997              0            1    N                 Y
# 4998              0            0    N                 Y
# 4999              0            0    N                 Y
#
#                                         review_headline  \
# 0                                            Five Stars
# 1     Gift card for the greatest selection of items ...
# 2                                            Five Stars
# 3                                              One Star
# 4                                            Five Stars
# ...                                                 ...
# 4995                                          Two Stars
# 4996                                         Five Stars
# 4997  Great brass couplings but it sprung a pin-hole...
# 4998                                         Five Stars
# 4999                            What to give a Graduate
#
#                                             review_body  year review_date  \
# 0                Great birthday gift for a young adult.  2015  2015-08-31
# 1     It's an Amazon gift card and with over 9823983...  2015  2015-08-31
# 2                                                  Good  2015  2015-08-31
# 3                                                  Fair  2015  2015-08-31
# 4     I can't believe how quickly Amazon can get the...  2015  2015-08-31
# ...                                                 ...   ...         ...
# 4995           Box was not as nice as it looks on line.  2015  2015-08-04
# 4996                        Great last minute gift idea  2015  2015-08-04
# 4997  Great brass couplings but it sprung a pin-hole...  2015  2015-08-04
# 4998                                  It's a gift card.  2015  2015-08-04
# 4999  Perfect gift for a high school grad; appreciat...  2015  2015-08-04
#
#      product_category
# 0           Gift Card
# 1           Gift Card
# 2           Gift Card
# 3           Gift Card
# 4           Gift Card
# ...               ...
# 4995        Gift Card
# 4996        Gift Card
# 4997        Gift Card
# 4998        Gift Card
# 4999        Gift Card
#
# [5000 rows x 16 columns]

# %% [markdown]
# # Release Resources

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
# Out:
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>

# %%
# %%javascript
#
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {
#     // NoOp
# }
